# %% [markdown]
# # 🚀 TWSE App APK 編譯器 v2
#
# 點擊 **Runtime → Run all** 自動編譯！
#
# ⏱️ 預計時間：20-30 分鐘

# %%
# Step 1: 清理並 Clone 最新程式碼
# !rm -rf twse-app .buildozer
# !git clone https://github.com/yungtang20/twse-app.git
# %cd twse-app
# !ls -la

# %%
# Step 2: 安裝 Buildozer 和依賴
# !pip install --quiet buildozer cython
# !apt-get update -qq
# !apt-get install -qq -y \
    build-essential git ffmpeg \
    libsdl2-dev libsdl2-image-dev libsdl2-mixer-dev libsdl2-ttf-dev \
    libportmidi-dev libswscale-dev libavformat-dev libavcodec-dev \
    zlib1g-dev libgstreamer1.0 gstreamer1.0-plugins-base gstreamer1.0-plugins-good \
    zip unzip openjdk-17-jdk autoconf libtool pkg-config \
    libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
print('✅ 依賴安裝完成')

# %%
# Step 3: 驗證 Python 語法
import subprocess
import sys

files_to_check = ['main.py', 'src/supabase_client.py', 'src/plugin_engine.py']
all_ok = True

for f in files_to_check:
    result = subprocess.run([sys.executable, '-m', 'py_compile', f], capture_output=True, text=True)
    if result.returncode != 0:
        print(f'❌ 語法錯誤: {f}')
        print(result.stderr)
        all_ok = False
    else:
        print(f'✅ {f}')

if all_ok:
    print('\n🎉 所有檔案語法正確！')
else:
    print('\n⚠️ 請修復語法錯誤後再繼續')

# %%
# Step 4: 編譯 APK (這是主要步驟，約 15-25 分鐘)
# !buildozer android debug

# %%
# Step 5: 下載 APK
from google.colab import files
import glob
import os

# 搜尋 APK
apk_patterns = ['bin/*.apk', '.buildozer/android/platform/*/dists/*/bin/*.apk']
apk_files = []
for pattern in apk_patterns:
    apk_files.extend(glob.glob(pattern))

if apk_files:
    for apk in apk_files:
        size_mb = os.path.getsize(apk) / (1024 * 1024)
        print(f'✅ 找到 APK: {apk} ({size_mb:.1f} MB)')
        files.download(apk)
else:
    print('❌ APK 未找到')
    print('請檢查上方編譯日誌中的錯誤訊息')
