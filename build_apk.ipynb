# %% [markdown]
# # 🚀 TWSE App APK 編譯器
# 點擊上方選單 **Runtime → Run all** 即可自動編譯 APK！

# %%
# Step 1: 清理舊檔案並 Clone 最新程式碼
# !rm -rf twse-app
# !git clone https://github.com/yungtang20/twse-app.git
# %cd twse-app

# %%
# Step 2: 安裝 Buildozer
# !pip install --upgrade buildozer cython virtualenv
# !apt-get update && apt-get install -y \
    python3-pip \
    build-essential \
    git \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good \
    zip \
    unzip \
    openjdk-17-jdk \
    autoconf \
    libtool \
    pkg-config \
    libncurses5-dev \
    libncursesw5-dev \
    libtinfo5 \
    cmake \
    libffi-dev \
    libssl-dev

# %%
# Step 3: 編譯 APK (約 15-30 分鐘)
# !buildozer android debug 2>&1 | tail -100

# %%
# Step 4: 下載 APK
from google.colab import files
import glob

apk_files = glob.glob('bin/*.apk')
if apk_files:
    for apk in apk_files:
        print(f'✅ 找到 APK: {apk}')
        files.download(apk)
else:
    print('❌ APK 未找到，請檢查編譯日誌')
